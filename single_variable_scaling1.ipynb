# %% [markdown]
# <a href="https://colab.research.google.com/github/podobongbong/the_project/blob/main/single_variable_scaling1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/podobongbong/the_project.git
# Out:
# Cloning into 'the_project'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 131.08 KiB | 7.28 MiB/s, done.

# %%
import os
os.chdir('/content/the_project') # Changed directory to where the CSV file likely exists
import pandas as pd

# Updated path to reflect the CSV's location in the cloned repo
data = pd.read_csv('energy.csv')

data.columns = ['year','city','district','type','jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']

#일단 총계 데이터만 사용함
data = data[data['type']=='총계']

monthly_columns = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
aggregated_data = data.groupby(['year','city'])[monthly_columns].sum().reset_index()

# Updated path for the output CSV as well
aggregated_data.to_csv('total_aggregated_city_energy.csv', index=False)

# %%
#%% DATA PREP
import numpy as np
from sklearn.preprocessing import MinMaxScaler
seoul_data = aggregated_data[aggregated_data['city'] == '서울특별시'].drop(columns=['city']).set_index('year')
busan_data = aggregated_data[aggregated_data['city'] == '부산광역시'].drop(columns=['city']).set_index('year')

energy_data_seoul = seoul_data.values.flatten()
energy_data_busan = busan_data.values.flatten()

# Normalize the data using MinMaxScaler
scaler_seoul = MinMaxScaler()  # Use separate scaler for Seoul
scaler_busan = MinMaxScaler()  # Use separate scaler for Busan
# Normalize Seoul data
energy_data_seoul_scaled = scaler_seoul.fit_transform(energy_data_seoul.reshape(-1, 1)).flatten()

# Normalize Busan data
energy_data_busan_scaled = scaler_busan.fit_transform(energy_data_busan.reshape(-1, 1)).flatten()

# %%
#%% SLIDING WINDOW
# Function to create sliding window samples
def create_sliding_window(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])  # Take the previous 'window_size' months
        y.append(data[i])  # The target is the next month's consumption
    return np.array(X), np.array(y)

WINDOW_SIZE = 12
TOTAL_MONTHS = 240

# Create sliding window samples for Seoul and Busan
X_seoul, y_seoul = create_sliding_window(energy_data_seoul_scaled, WINDOW_SIZE)
X_busan, y_busan = create_sliding_window(energy_data_busan_scaled, WINDOW_SIZE)

# Split Busan data into training and test sets (hold out the last 12 months for testing)
X_train_busan = X_busan[:-12]
y_train_busan = y_busan[:-12]
X_test_busan = X_busan[-12:]
y_test_busan = y_busan[-12:]

# %%
#%% Model creation
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Reshape # Import Reshape

# Define the LSTM model structure
def build_model(window_size):
    input_layer = Input(shape=(window_size,), name='Input')
    # Reshape the input to 3D for the LSTM layer
    reshaped_input = Reshape((window_size, 1))(input_layer)
    lstm_out = LSTM(64, activation='tanh', name='LSTM_Layer')(reshaped_input)

    # Dense layers for final prediction
    dense_1 = Dense(32, activation='relu', name='Dense_1')(lstm_out)
    dense_2 = Dense(16, activation='relu', name='Dense_2')(dense_1)

    # Output layer for predicting the next month's energy consumption
    output_layer = Dense(1, activation='linear', name='Output')(dense_2)

    # Create the model
    model = Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    return model

# Create the LSTM model
model = build_model(WINDOW_SIZE)

# Print model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 12)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 12, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ LSTM_Layer (LSTM)                    │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("Pretraining on Seoul data (2004-2023)...")
history_pretrain = model.fit(X_seoul, y_seoul, epochs=50, batch_size=32, validation_split=0.2)

# Fine-tune the model on Busan's data (train on 2004-2022)
print("Fine-tuning on Busan data (2004-2022)...")
history_finetune = model.fit(X_train_busan, y_train_busan, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Pretraining on Seoul data (2004-2023)...
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.2354 - mae: 0.4367 - val_loss: 0.2567 - val_mae: 0.4640
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1891 - mae: 0.3847 - val_loss: 0.1937 - val_mae: 0.3896
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1315 - mae: 0.3113 - val_loss: 0.1303 - val_mae: 0.2968
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0820 - mae: 0.2269 - val_loss: 0.0727 - val_mae: 0.2048
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0478 - mae: 0.1672 - val_loss: 0.0428 - val_mae: 0.1737
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0343 - mae: 0.1575 - val_loss: 0.0619 - val_mae: 0.2083
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0426 - mae: 0.1734 - val_loss: 0.0607 - val_mae: 0.2059
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0389 - mae: 0.1655 - val_loss: 0.0447 - val_mae: 0.1799
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0315 - mae: 0.1528 - val_loss: 0.0452 - val_mae: 0.1739
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0359 - mae: 0.1593 - val_loss: 0.0483 - val_mae: 0.1749
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0333 - mae: 0.1522 - val_loss: 0.0453 - val_mae: 0.1736
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0342 - mae: 0.1569 - val_loss: 0.0435 - val_mae: 0.1779
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0363 - mae: 0.1674 - val_loss: 0.0464 - val_mae: 0.1829
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0353 - mae: 0.1612 - val_loss: 0.0463 - val_mae: 0.1827
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0333 - mae: 0.1567 - val_loss: 0.0435 - val_mae: 0.1777
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0303 - mae: 0.1488 - val_loss: 0.0429 - val_mae: 0.1748
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0322 - mae: 0.1569 - val_loss: 0.0433 - val_mae: 0.1732
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0321 - mae: 0.1510 - val_loss: 0.0429 - val_mae: 0.1738
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0314 - mae: 0.1494 - val_loss: 0.0426 - val_mae: 0.1754
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0327 - mae: 0.1563 - val_loss: 0.0435 - val_mae: 0.1774
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0329 - mae: 0.1581 - val_loss: 0.0432 - val_mae: 0.1768
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0331 - mae: 0.1568 - val_loss: 0.0424 - val_mae: 0.1752
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0313 - mae: 0.1552 - val_loss: 0.0420 - val_mae: 0.1732
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0326 - mae: 0.1556 - val_loss: 0.0419 - val_mae: 0.1738
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0314 - mae: 0.1533 - val_loss: 0.0422 - val_mae: 0.1747
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0324 - mae: 0.1563 - val_loss: 0.0424 - val_mae: 0.1749
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0322 - mae: 0.1540 - val_loss: 0.0416 - val_mae: 0.1735
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0316 - mae: 0.1540 - val_loss: 0.0413 - val_mae: 0.1725
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0294 - mae: 0.1465 - val_loss: 0.0414 - val_mae: 0.1728
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0285 - mae: 0.1452 - val_loss: 0.0410 - val_mae: 0.1718
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0323 - mae: 0.1537 - val_loss: 0.0407 - val_mae: 0.1711
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0294 - mae: 0.1492 - val_loss: 0.0409 - val_mae: 0.1716
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0313 - mae: 0.1515 - val_loss: 0.0415 - val_mae: 0.1730
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0309 - mae: 0.1513 - val_loss: 0.0407 - val_mae: 0.1712
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0284 - mae: 0.1445 - val_loss: 0.0397 - val_mae: 0.1687
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0332 - mae: 0.1571 - val_loss: 0.0397 - val_mae: 0.1687
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0290 - mae: 0.1458 - val_loss: 0.0394 - val_mae: 0.1679
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0325 - mae: 0.1563 - val_loss: 0.0398 - val_mae: 0.1693
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0294 - mae: 0.1489 - val_loss: 0.0403 - val_mae: 0.1702
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0301 - mae: 0.1512 - val_loss: 0.0383 - val_mae: 0.1654
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0287 - mae: 0.1477 - val_loss: 0.0382 - val_mae: 0.1653
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0289 - mae: 0.1454 - val_loss: 0.0383 - val_mae: 0.1658
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0270 - mae: 0.1424 - val_loss: 0.0378 - val_mae: 0.1647
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0260 - mae: 0.1390 - val_loss: 0.0373 - val_mae: 0.1634
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0264 - mae: 0.1422 - val_loss: 0.0364 - val_mae: 0.1612
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0269 - mae: 0.1424 - val_loss: 0.0383 - val_mae: 0.1639
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0267 - mae: 0.1404 - val_loss: 0.0358 - val_mae: 0.1593
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0272 - mae: 0.1424 - val_loss: 0.0335 - val_mae: 0.1531
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0291 - mae: 0.1444 - val_loss: 0.0338 - val_mae: 0.1543
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0252 - mae: 0.1382 - val_loss: 0.0368 - val_mae: 0.1581
# Fine-tuning on Busan data (2004-2022)...
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0124 - mae: 0.0894 - val_loss: 0.0204 - val_mae: 0.1219
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0124 - mae: 0.0904 - val_loss: 0.0256 - val_mae: 0.1387
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0128 - mae: 0.0924 - val_loss: 0.0251 - val_mae: 0.1372
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0140 - mae: 0.0977 - val_loss: 0.0234 - val_mae: 0.1321
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0133 - mae: 0.0942 - val_loss: 0.0298 - val_mae: 0.1503
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0120 - mae: 0.0909 - val_loss: 0.0215 - val_mae: 0.1261
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0118 - mae: 0.0890 - val_loss: 0.0426 - val_mae: 0.1783
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0138 - mae: 0.0967 - val_loss: 0.0216 - val_mae: 0.1264
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0123 - mae: 0.0902 - val_loss: 0.0223 - val_mae: 0.1287
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0128 - mae: 0.0937 - val_loss: 0.0213 - val_mae: 0.1253
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0135 - mae: 0.0944 - val_loss: 0.0209 - val_mae: 0.1243
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0124 - mae: 0.0927 - val_loss: 0.0251 - val_mae: 0.1373
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0127 - mae: 0.0933 - val_loss: 0.0421 - val_mae: 0.1776
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0132 - mae: 0.0949 - val_loss: 0.0185 - val_mae: 0.1161
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0127 - mae: 0.0903 - val_loss: 0.0259 - val_mae: 0.1396
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0116 - mae: 0.0867 - val_loss: 0.0414 - val_mae: 0.1761
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0123 - mae: 0.0907 - val_loss: 0.0182 - val_mae: 0.1150
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0117 - mae: 0.0897 - val_loss: 0.0316 - val_mae: 0.1538
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0128 - mae: 0.0955 - val_loss: 0.0246 - val_mae: 0.1356
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0122 - mae: 0.0894 - val_loss: 0.0198 - val_mae: 0.1207

# %%
#%% Model Testing

# Test the model on unseen data from 2023 (Busan)
print("Testing on Busan data (2023)...")
test_loss, test_mae = model.evaluate(X_test_busan, y_test_busan)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Predict on the test data
predictions = model.predict(X_test_busan)

# Rescale predictions back to the original scale (dummy scaling in this case)
predictions_rescaled = scaler_busan.inverse_transform(predictions.reshape(-1, 1)).flatten()
# Out:
# Testing on Busan data (2023)...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0173 - mae: 0.1141
# Test Loss: 0.017268365249037743, Test MAE: 0.1141379103064537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
import matplotlib.pyplot as plt

# 1. Plot training and validation loss during pretraining and fine-tuning
def plot_training_history(history_pretrain, history_finetune):
    plt.figure(figsize=(12, 6))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(history_pretrain.history['loss'], label='Pretrain Loss (Seoul)')
    plt.plot(history_pretrain.history['val_loss'], label='Pretrain Val Loss (Seoul)')
    plt.plot(history_finetune.history['loss'], label='Finetune Loss (Busan)')
    plt.plot(history_finetune.history['val_loss'], label='Finetune Val Loss (Busan)')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot MAE
    plt.subplot(1, 2, 2)
    plt.plot(history_pretrain.history['mae'], label='Pretrain MAE (Seoul)')
    plt.plot(history_pretrain.history['val_mae'], label='Pretrain Val MAE (Seoul)')
    plt.plot(history_finetune.history['mae'], label='Finetune MAE (Busan)')
    plt.plot(history_finetune.history['val_mae'], label='Finetune Val MAE (Busan)')
    plt.title('Training and Validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 2. Plot predictions vs actual values for Busan (2023)
def plot_predictions(y_true, y_pred, title='Predictions vs Actuals (Busan 2023)'):
    plt.figure(figsize=(10, 6))
    plt.plot(y_true, label='Actual Values', marker='o')
    plt.plot(y_pred, label='Predicted Values', marker='x')
    plt.title(title)
    plt.xlabel('Months')
    plt.ylabel('Energy Consumption')
    plt.legend()
    plt.show()

# Call the functions to visualize training and results
plot_training_history(history_pretrain, history_finetune)
plot_predictions(y_test_busan, predictions_rescaled)
